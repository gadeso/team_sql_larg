# %%
import pandas as pd
import datetime
import sqlite3
import os

# %%
clase_1 = pd.read_csv('../data/clase_1.csv', delimiter=';')
clase_2 = pd.read_csv('../data/clase_2.csv', delimiter=';')
clase_3 = pd.read_csv('../data/clase_3.csv', delimiter=';')
clase_4 = pd.read_csv('../data/clase_4.csv', delimiter=';')

# %%
clase_1
# Out:
#                   Nombre                           Email   Promoción  \
# 0           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 5           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 10         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
alumnos = pd.concat([clase_1, clase_2, clase_3, clase_4])

# %%
alumnos.dtypes
# Out:
# Nombre                 object
# Email                  object
# Promoción              object
# Fecha_comienzo         object
# Campus                 object
# Proyecto_HLF           object
# Proyecto_EDA           object
# Proyecto_BBDD          object
# Proyecto_ML            object
# Proyecto_Deployment    object
# Proyecto_WebDev        object
# Proyecto_FrontEnd      object
# Proyecto_Backend       object
# Proyecto_React         object
# Proyecto_FullSatck     object
# dtype: object

# %%
alumnos.sort_values(ascending=True, by='Nombre')
# Out:
#                   Nombre                           Email   Promoción  \
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 28      Aitana Sebastián      Aitana_Sebastián@gmail.com  Septiembre
# 33         Albino Macias         Albino_Macias@gmail.com  Septiembre
# 45   Alejandra Vilaplana   Alejandra_Vilaplana@gmail.com     Febrero
# 25        Amor Larrañaga        Amor_Larrañaga@gmail.com  Septiembre
# 13         Anita Heredia         Anita_Heredia@gmail.com  Septiembre
# 17       Carlito Carrión       Carlito_Carrión@gmail.com     Febrero
# 19         Chita Mancebo         Chita_Mancebo@gmail.com     Febrero
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 48          Cleto Montes          Cleto_Montes@gmail.com     Febrero
# 27           Cleto Plana           Cleto_Plana@gmail.com  Septiembre
# 21      Cristian Sarabia      Cristian_Sarabia@gmail.com     Febrero
# 46       Daniel Rosselló       Daniel_Rosselló@gmail.com     Febrero
# ...

# %%
alumnos["Fecha_comienzo"] = pd.to_datetime(alumnos['Fecha_comienzo'], dayfirst=True)

# %%
alumnos.dtypes
# Out:
# Nombre                         object
# Email                          object
# Promoción                      object
# Fecha_comienzo         datetime64[ns]
# Campus                         object
# Proyecto_HLF                   object
# Proyecto_EDA                   object
# Proyecto_BBDD                  object
# Proyecto_ML                    object
# Proyecto_Deployment            object
# Proyecto_WebDev                object
# Proyecto_FrontEnd              object
# Proyecto_Backend               object
# Proyecto_React                 object
# Proyecto_FullSatck             object
# dtype: object

# %%
alumnos = alumnos.reset_index()

# %%
alumnos.drop(columns='index', inplace=True)

# %%
promociones = alumnos[["Promoción","Fecha_comienzo"]]

# %%
promociones.head()
# Out:
#     Promoción Fecha_comienzo
# 0  Septiembre     2023-09-18
# 1  Septiembre     2023-09-18
# 2  Septiembre     2023-09-18
# 3  Septiembre     2023-09-18
# 4  Septiembre     2023-09-18

# %%
nombre_alumnos = alumnos[["Nombre", "Email"]]

# %%
nombre_alumnos
# Out:
#                   Nombre                           Email
# 0           Jafet Casals          Jafet_Casals@gmail.com
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com
# 2          Onofre Adadia         Onofre_Adadia@gmail.com
# 3           Merche Prada          Merche_Prada@gmail.com
# 4           Pilar Abella          Pilar_Abella@gmail.com
# 5           Leoncio Tena          Leoncio_Tena@gmail.com
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com
# 9      Clementina Santos     Clementina_Santos@gmail.com
# 10         Daniela Falcó         Daniela_Falcó@gmail.com
# 11         Abraham Vélez         Abraham_Vélez@gmail.com
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com
# 13         Anita Heredia         Anita_Heredia@gmail.com
# 14             Eli Casas             Eli_Casas@gmail.com
# ...

# %%
al_pro = pd.read_csv('../data/alumnos_proyectos.csv')

# %%
al_pro.to_csv('../data/proyectos_alumnos.csv')

# %%
al_pro
# Out:
#      alumno_id proyecto_id     apto
# 0            1           1     Apto
# 1            2           1     Apto
# 2            3           1     Apto
# 3            4           1     Apto
# 4            5           1     Apto
# ..         ...         ...      ...
# 515         48          10     Apto
# 516         49          10     Apto
# 517         50          10  No Apto
# 518         51          10     Apto
# 519         52          10     Apto
#
# [520 rows x 3 columns]

# %%
al_pro[['proyecto_id']]
# Out:
#     proyecto_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 515          10
# 516          10
# 517          10
# 518          10
# 519          10
#
# [520 rows x 1 columns]

# %%
al_pro.rename(columns={'alumno_id':'alumnoid'}, inplace=True)

# %%
al_pro.rename(columns={'proyecto_id':'proyectoid'}, inplace=True)

# %%
al_pro.to_csv('../data/pro_al.csv')

# %%
al_pro.replace('Proyecto_FullSatck', 10, inplace=True)

# %%
al_pro
# Out:
#      alumnoid proyectoid     apto
# 0           1          1     Apto
# 1           2          1     Apto
# 2           3          1     Apto
# 3           4          1     Apto
# 4           5          1     Apto
# ..        ...        ...      ...
# 515        48         10     Apto
# 516        49         10     Apto
# 517        50         10  No Apto
# 518        51         10     Apto
# 519        52         10     Apto
#
# [520 rows x 3 columns]
